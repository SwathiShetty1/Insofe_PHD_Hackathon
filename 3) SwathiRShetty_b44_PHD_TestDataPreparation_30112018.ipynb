# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import os
import time

import re  
import nltk

from nltk.corpus import stopwords
from nltk.corpus import RegexpTokenizer as regextoken
from nltk.stem.porter import PorterStemmer
from nltk.stem import WordNetLemmatizer
from nltk import pos_tag
import pickle

from sklearn.cluster import KMeans
from sklearn.metrics import adjusted_rand_score

from sklearn.decomposition import PCA
from __future__ import print_function

# %%
os.getcwd()
# Out:
# '/Users/z066910/Desktop/PHDHackathon'

# %% [markdown]
# #### Import Test data

# %%
testds=pd.read_csv('GrievancesData_Test.csv')

# %%
testds.dtypes
# Out:
# GrievanceID             object
# BankID                  object
# State                   object
# DateOfGrievance         object
# Grievance_Category      object
# GrievanceDescription    object
# LineOfBusiness          object
# ResolutionComments      object
# Disputed                object
# DateOfResolution        object
# dtype: object

# %%
testds.describe()
# Out:
#        GrievanceID    BankID   State DateOfGrievance  \
# count        27954     27954   27879           27954
# unique       27954        22      61            1168
# top      GID436025  Bank5373  State9      2014-01-19
# freq             1      8221    3839             727
#
#                               Grievance_Category  \
# count                                      27954
# unique                                        59
# top     Loan servicing, payments, escrow account
# freq                                        4403
#
#                                      GrievanceDescription LineOfBusiness  \
# count                                               27954          27954
# unique                                              24137              4
# top      I was shocked when I reviewed my credit repor...    Credit card
# freq                                                    6           9561
#
#              ResolutionComments Disputed DateOfResolution
# count                     27954    27954            27954
# unique                        4        2             1198
# top     Closed with explanation       No       2014-02-19
# freq                      23505    22524              291

# %%
testds.head(1)
# Out:
#   GrievanceID    BankID    State DateOfGrievance  \
# 0   GID512414  Bank5334  State43      2016-01-19
#
#                          Grievance_Category  \
# 0  Loan servicing, payments, escrow account
#
#                                 GrievanceDescription LineOfBusiness  \
# 0   I currently have a mortgage with Flag star ba...       Mortgage
#
#         ResolutionComments Disputed DateOfResolution
# 0  Closed with explanation       No       2016-01-30

# %%
testds.tail(1)
# Out:
#       GrievanceID    BankID    State DateOfGrievance  \
# 27953   GID502376  Bank5372  State22      2015-08-23
#
#                                       Grievance_Category  \
# 27953  Problem with a credit reporting company's inve...
#
#                                     GrievanceDescription LineOfBusiness  \
# 27953   See attached document showing payments still ...       Mortgage
#
#             ResolutionComments Disputed DateOfResolution
# 27953  Closed with explanation       No       2015-09-23

# %%
print(testds.columns)
# Out:
# Index([u'GrievanceID', u'BankID', u'State', u'DateOfGrievance',
#        u'Grievance_Category', u'GrievanceDescription', u'LineOfBusiness',
#        u'ResolutionComments', u'Disputed', u'DateOfResolution'],
#       dtype='object')

# %%
#Check for the shape (no.of rows,columns) of the data
print(testds.shape)
# Out:
# (27954, 10)

# %%
#Check for missing values in the data
print(testds.isnull().sum())
# Out:
# GrievanceID              0
# BankID                   0
# State                   75
# DateOfGrievance          0
# Grievance_Category       0
# GrievanceDescription     0
# LineOfBusiness           0
# ResolutionComments       0
# Disputed                 0
# DateOfResolution         0
# dtype: int64

# %%
#Frequency Count
#testds.groupby('BankID').size()
#testds.groupby('GrievanceID').size()
#testds.groupby('State').size()
#testds.groupby('DateOfGrievance').size()
#testds.groupby('GrievanceDescription').size()
#No.o unique text 24137
#testds.groupby('LineOfBusiness').size()
#testds.groupby('ResolutionComments').size()
#Closed with explanation -> # texts 23505
#testds.groupby('Disputed').size()
# Disputed = Yes -> # grievances 5430
#testds.groupby('DateOfResolution').size()

# %%
#Remove duplicate records

#Deleting if records are repeting just with different grievance id
testdf=testds.drop_duplicates(['BankID','State','DateOfGrievance','Grievance_Category','GrievanceDescription','LineOfBusiness','ResolutionComments','Disputed','DateOfResolution'],keep='first')

# %%
testdf.shape
# Out:
# (24165, 10)

# %%
#Reset the index of the deduped data
testdf.reset_index()
testdf1=testdf.reset_index(drop=True)
testdf1.head(1)
# Out:
#   GrievanceID    BankID    State DateOfGrievance  \
# 0   GID512414  Bank5334  State43      2016-01-19
#
#                          Grievance_Category  \
# 0  Loan servicing, payments, escrow account
#
#                                 GrievanceDescription LineOfBusiness  \
# 0   I currently have a mortgage with Flag star ba...       Mortgage
#
#         ResolutionComments Disputed DateOfResolution
# 0  Closed with explanation       No       2016-01-30

# %%
#Data for text mining
datatxt= testdf1[['GrievanceID','GrievanceDescription']]

# %%
#Define function to preprocess text
def text_to_words( text ):
    start = time.time()
    #letters_only = re.sub("[^a-zA-Z0-9$%!]", " ", text) 
    letters_only = re.sub("[^a-zA-Z]", " ", text) 
    words = letters_only.lower().split()
    stop_words = stopwords.words('english')
    #Extending the stop words list by adding data specific unwanted words to the list
    stop_words.extend(['xx','xxx','xxxx','bank america','bank','citi','ocwen','ocwens','gl','rp','fitbit','cement','mls','lfs','reo','hhf','be','di','pt','ax','sp','america','american','bankamericard','americans','americas','aaa','aa','aafes','us','usa','usbank'])
    stops = set(stop_words)  
    lm=WordNetLemmatizer()
    meaningful_words = [lm.lemmatize(w,pos='v') for w in words if not w in stops]
    
    #Convert plurals to singular
    #postg=pos_tag(meaningful_words)
    #newwords=[w[0].rstrip("s") if w[1]=='NNS' else w[0] for w in postg]
    
    #ps = PorterStemmer()
    #meaningful_words = [ps.stem(w) for w in words if not w in stops]
    
    return( " ".join( meaningful_words )) 
    #return( " ".join( newwords )) 
    
    end = time.time()
    print("Time elapsed for execution = ", end - start)

# %%
#No.of texts to process
num_texts = datatxt["GrievanceDescription"].size
print(num_texts)
# Out:
# 24165

# %%
#Define function to clean text
def cleantxt(IP,rec):
    #Initialize an empty list to hold the clean texts
    clean_reviews = []
    start = time.time()
    #Loop over each text
    for i in range(0, rec):
        #Call function for each text, and add the result to the list of clean reviews
        clean_reviews.append(text_to_words(IP["GrievanceDescription"][i]))
    
    end = time.time()
    print("Time elapsed for execution = ", end - start)
    return clean_reviews

# %%
#Call clean text function to create corpus of cleaned text, all data (train)
Tclean_reviews=cleantxt(datatxt,rec=num_texts)
Tclean_reviews
# Out:
# Time elapsed for execution =  29.7082738876
# [u'currently mortgage flag star payment late reach flag star loan year first time payment late due personal issue currently current payments receive notice loan go service interest loan transfer company address issue look company nothing horror stories post avoid loan transfer',
#  u'auto finance repossess subsequently sell car husband chapter bankruptcy inquire regain possession rectify account tell call back bankruptcy call back already sell car credit report show repossession recovery amount owe give chance regain possession car take payments',
#  u'fell behind payments back follow really unreasonable modification modification place loan years years old never live pay months modification payment go month fell behind due fact health problems medical condition go time also lose month income due family members move home contribute household time receive notice mortgage company payment date letter contact point contact person inform difficulty need time contact mortgage company man answer phone tell inform much could make payment await tax return within week amount go turn account lawyer collection foreclosue precede attempt since make payment order get catch take payment order help even get response law office send account collection meantime get behind look another modification forbearance get time get finance back track get letter someone handle compliants put side story tell behind say help wo n even return call talk feel stress due son fear streets',
#  u'home parcel land first year live home mail real estate tax bill time mortgage company escrow account suppose handle bill flash forward year receive delinquent tax notice mail call ask pay parcel send ask fax delinquent tax notice directly tell would take business days handle hear update call back tell contact tax collector say tax date call tax collector confirm tell contact parcel happen one pay ask unpaid parcel tell parcel total pay call back rd time let know ask tax collector wrong parcel sure since fax unpaid parcel never pay parcel number even mention woman name phone minutes supposedly take care situation give unpaid parcel number multiple time ask mortgage company would pay additional fee penalties mistake tell would say send request inquire unpaid parcel would call give update receive call update call get whole story put information system proceed tell parcel list file tell repeatedly say put request confirm third parcel even though suppose do already previous people say call back confirm everything verify tax pay',
#  u'mortgage home assign loan transfer loan escrowed replace release replacement complete transfer loan service include insurance escrow fund green tree service green tree advise escrow fund refuse release escrow fund pay roof',
#  u'accept credit card barclays initial disclosure provide indicate promotional rate apr purchase months balance transfer months upon receive card disclosure provide reference promotional rate balance transfer therefore call company discuss tell promotional purchase therefore submit complaint website several back forth responses letter receive still indicate promotional rate purchase already express initially disclose therefore deceptive consumer make credit decision base initially information provide appear false provide link provide term condition card include promotional rate balance transfer concern deceptive practice might conduct https www barclaycardus com apply land action www barclaycardus com app japply lp tncs jsp',
#  u'would like credit full fraudcharges include charge products andservices claim offer notsure apply creditwith company one maybe associate victim fraud feel like scammed agained reason n use credit card norapply credit n feel safe',
#  u'decrease monthly payments try deal navient formerly regard private loan take college tuition name mother primary borrower cosigner admit phone repeatedly n give money phone exact amount want exorbitant document phone call start deal via paper letter take kindly loan primary borrower expect well month payments unreasonable income give multiple financial statements phone apparently n put system next time talk someone say nothing file give statements agree month much nothing else available ask recommend say even bother send amount actually afford without lose home car need job enough anything worthwhile make fun go career path hop college demand know loan mother primary borrower one lower payment plan confirmation number payments take check account receive letter mail state payment plan reject reason try find write yet even date letter send money still take account navient also still receive letter phone call particular account delinquent even though make payments wits end try contact via paper refuse talk phone anymore result panic anxiety attack every time call n want go default ca n afford anything close demand loan use forbearance time loan pay every months put almost make wish never go school also wish school do better job educate private loan really instead sign piece paper money towards tuition federal loan reasonable repayment plan base income ca n private loan way please help advise',
#  u'charge fee speak overnight change mortgage number give file indymac mortgage service clear way everybody remain home charge another modification fee agree order keep home build people mother',
#  u'problems customer service submit documentation accordance internal policy protocol request student loan discharge due false certification id theft include letter material fact examine nature dispute history force compliance multiple certifications signature include government issue identification social security card along police report cite fraudulent account currently hold name social security number still continue insist fulfil requirements discharge submit court judgment indicate victim fraud herein lie problem person arrest prosecute illicit activities arise personal information compromise fortunately wrongly charge crime due illegal usage personal information condition must applicable order petition court verdict submit request certificate identity theft judicial find factual innocence condition satisfy provide copy court judgment however nullify claim disqualify submit mean proof fraudulent loan discharge accord federal regulation cfr e ii b entitle submit authentic signature specimens mean identification correspond mean identification falsely use obtain loan qualify loan discharge due identity theft lieu court judgment file report federal trade commission local police department ombudsman ombudsman contact credit bureaus bar impossibility court verdict follow instructions precisely act willful non compliance abide regulations discharge fraudulently obtain loan formally request close account remove credit report provide restitution take remuneration restore years damage do credit retrieve expenditure time lose argue case loan guarantor originator mitigate stress monies rightfully belong return follow excerpt letter submit notify employer wag garnish student loan never apply colleges never attend call guarantor loan speak representative offer alternative repayment plan prolongation wage garnishment though vehemently inform representative responsible party knowledge say loan even live california time student loan open initially refuse pay loan turn monies take salary tax refund young uninformed seem recobank e matter finally begrudgingly acquiesce enter rehabilitation program fraudulently file loan yet file tax another take irs offset year upwards nine thousand dollars take learn could file discharge due id theft even submit continue keep matter unresolved downright exasperate',
#  u'disappoint regulatorydept help resolve fraudulant loan ff aka one west case regulatorydept',
#  u'speak green tree representatives annual escrow acct disclosure statement reference pmi loan recieved accord original document pmi however loan sell green tree months ago notice green tree deduct escrow acct never agree pay green tree support document sign referance loan term pmi would like take care soon possible stress think green tree ask expect refund time pay wrong amount call green tree handful time issue also fax letter show support document dont believe days call write still take care enough time since bring attention attemp try get honest fair response dont believe green tree handle professional manner disappoint get responce matter honesty look green tree make mistake ready fix compensate something owe pmi would bring proof quickly would appriciate kind attempt fix',
#  u'foreword explanation aware husband already file similar grievance morning familiar detail often pay bill keep record payments update speak agree add complaint important understand history reason things turn way happen believe set increase monthly payment order mark loan delinquent proceed collect non interest bear principal balance know significant amount cash produce immediately hop ca n move proceed foreclosure possession condo husband apply grant loan modification give stay amount reduce payments prevent foreclosure save mortgage server immediately sell loan get go show true color increase payments immediately month call daily find someone senior enough honest enough tell reason increase mean surplus payments agree could deduct monthly pay amount equalize however continue send statements late fee interest add pay additional pay late fee penalties every statement needle say wrap time days months subterfuges yes right take charge still send statements increase charge fee interest finally many months persistence finally admit pay toward non interest bear principal balance remind balance leave payments toward balance part sign agreement first encounter desire get unpaid balance book one way another check escrow history write letter write summary escrow balance hundred dollars escrow minus increase monthly payments intentionally actively alert adjust escrow enough make deficiency constant daily phone call month date receive payments tell late transform call constant harasser since know payments already make receive notice monthly payments immediately put online recur payments open letter state serious delinquency check payments make timely fashion call first time realize payments go escrow double tell tx send breakdown year end escrow immediately never receive one year end paper come date shortage escrow believe work make fail create situation escrow become insurmountable shortage trigger substantial increase alert increase advance create superficial default trigger demand immediate payment know get demand letter last ni',
#  u'recently change mortgage loan servicer new company name act predatory place collection call payment make first always pay within grace period never day late payment complain say request write stop call write request way consider avoid horrassment first take service without notice dispatch local contractor enter home change lock remove belong needle say alarm guy door show show work order give number service contractor base state contractors would give name provide identification everything document action latest go around involve unjustified charge loan account tell phone could stop collection property tax escrow requirement note request must write give persons name fax number send produce write request fax early three weeks later write back say process request make regular payment p include escrow amount today get call time demand escrow amount late fee representative never state statutory legal statement debt collector go affirm recieved payment however would refund strike late fee charge put long hold least three time say try clear escrow issue standard statement could send write request write late fee instead tell representative call reason unless loan thirty days past due state dispute resolve write therefore state call reason unless thirty days past due reply continue call every five days n think legal debt collector act way hence description preditory',
#  u'sign e bill synchrony everything go fine change website sign userid passwords recognize call complain ask start send statements mail could get account new website call three time make request actually mail request also still receive statements constantly call leave message call real number meantime charge late charge n pay within certain time add interest want pay bill statement please help entity completely ruin credit',
#  u'withhold money monthly house payment fund escrow account pay property tax use fund account pay tax someone else property land collections county tax department since pay collections show additional amount part payoff amount mean charge property tax attorney request update payoff since error help tell wait refund county contact county advise refund mortgage company issue say mortgage company request fund owner property erroneously pay say make mistake attorney documentation show issue penalize make impossible refinance loan lower interest rate notice issue spend literally hobank try get resolve many time disconnect give incorrect call back number number route wrong department also give representatives call back number one call back leave several message tax department never return call want move loan company could accomplish refi show owe mean would come pocket hope reimbbank ement point',
#  u'mortgage send mortgage payment say short send back never receive confirm n receive never cash send hold department n exist end since day prior make mortgage payments time idea start dock days late since payment sell mortgage n receive information regard sale pay finally realize payments go make first payment month documentation proof payment institutions date back dock days late months payment send back explanation lates purchase mortgage purchase history well know payment send back idea take place able get mortgage since day lates top add day late dispute institutions comment back record correct adjustments warrant submit documentation bureaus base investigation give credit remove day lates two months idea show proof payment last years day late day late day late make sense anyone try contact last months get help regard explanation purchase history every time call get different person idea dock late give name manager need email documentation would get response days days ago send numerous email individual cobank e days get zero feedback need serious help issue prevent get new mortgage',
#  u'mortgage buy green tree husband lose job get behind try work arrangements green tree refuse payment unless bring current call several time day fax personal info payment history work fax co workers see pay payment threats take home pay another call another payment tell still payment behind need pay would bring current explain receive another call minutes later another account rep handle account threaten would void payment day would put days past due ask speak manager get phone say look call back next day ask payment void tell pull statement see reverse back account refuse payment except tactics use right try keep home purposely refuse payment damage credit make loose home tell file foreclosure believe would want push customer foreclosure payment past due try keep home always pay time husband lose job proof except payment void believe play game talk several people claim managers say look follow',
#  u'card suppose reward fuel purchase upon check statements amex site notice get reward certain gas station inform amex reply business consider gas station even though thats sell gas station part grocery market however gas station stand alone build corner connect anything else sometimes station brand sometimes brand locate co colorado lot gas station somehow part family reward come cash understand use card exclusively fuel find gas station fill consider gas station amex around area tons station ca n one lose cash reward station consider gas station amex card issue lot people amex offer card tons people card get huge amount reward money fuel purchase spend past two years particular gas station see reward reward shop contact amex speak say research find categorization correct far concern funny thing go onto amex account online look purchase say charge automate fuel category transportation fuel say buy groceries grocery store category merchandise supply groceries sure else scammed hundereds dollars past couple years say station gas station fee interaction amex',
#  u'able obtain refund amazon credit card jacket send back date credit issue second pair sticky sandal also return receipt jacket small line dog fur pay file custom declaration',
#  u'get flexible payment options due financial hardship unable pay student loan struggle months contact lender via email write letter response receive must contact via phone certain hobank tell multiple time impossible due work schedule write offer settle make arrangements write back always state help unless call purposefully contribute default account enter last letter receive state default occur contact check credit report already report default place collection agency weeks prior date email regard situation still discuss anything write phone make sense consolidate loan another lender situation cause credit report go',
#  u'pay mortgage biweekly basis send half payment time several years without problems sell loan nation star mortgage continue pay biweekly nation star begin send letter say put partial payment suspense account remainder mortgage payment receive letter regularly inaccurate say owe double regular payment time contact nation star regard letter tell disregard collection letter payments current continue pay biweekly ignore constant harass daily collection call inaccurate monthly letter tell fund suspense show inaccurate amount owe since find nation star report credit bureaus delinquent pay mortgage payments cause credit score drop point contact nation star review account tell right delinquent owe money protest attempt go record payments since take loan rudely tell fax information payments investigate print credit union record payments year fax information customer service rep fax number provide friday attempt follow nation star tuesday verify receive fax receive return call unacceptable error send double mortgage payment via ach stress situation request extra payment return check account cobank e nation star return money since record show delinquent',
#  u'keep get call loan behind loan call two months ago get set payment plan continue harass make threaten phone call make consecutive payments ask multiple time stop call always blame issue system error end rope n know else',
#  u'live california former mortgage holder go bankrupt sell loan green tree prior sell never hear company result sell green tree open escrow account pay property tax insurance never escrow account believe state california require lenders maintain escrow account mortgage fix rate year mortgage monthly mortgage payment pay monthly cover escrow payment property tax insurance accord monthly statement green tree regular monthly payment pay roughly per month require acknowledge designate apply escrow account recently make payment despite attempt comply term loan every year since green tree hold mortgage get bill dollars year supposedly escrow shortages every year different amount escrow shortages always dollars amount insurance property tax pay annually increase much justify increase dollars year green tree provide annual escrow account disclosure statement convolute calculation justify increase copy attach year days prior receive annual escrow account disclosure statement receive letter green tree state account current copy attach year contact green tree get someone explain calculations yet understand justification explanation n pay amount shortage green tree threaten increase amount regular monthly payment cover shortage find hard believe legal mortgage company charge borrower dollars per year maintain escrow account cheaper borrower pay property tax insurance borrower property tax insurance delinquent borrower able opt onerous escrow arrangement green tree able charge people dollars year suppose escrow shortages wonder require borrowers escrow account able pay property tax insurance avoid financial hardship green tree create currently stick mortgage company first opportunity make every effort change lenders n believe penalize stick company company voluntarily enter contract legal mortgage company require consumers escrow account cost hundreds dollars per year would cost consumer pay property tax insurance n know practice legal n definitely need investigate',
#  u'successor interest property locate california mortgage property currently default primarily lender inability renegotiate receive notification go foreclosure since contact lender reinstate delinquent lien one want talk put hold long time someone eventually come talk find reason work anything frustrate think want find way sell property',
#  u'get flexible payment options call cosigner multiple time per day advise call multiple time per day continue different number also multiple individuals break time take call without notify change pull credit report tell pay car note insurance taunt pay pay',
#  u'auto finance repossess subsequently sell car husband chapter bankruptcy inquire regain possession rectify account tell call back bankruptcy call back already sell car credit report show repossession recovery amount owe give chance regain possession car take payments',
#  u'mortgage buy green tree husband lose job get behind try work arrangements green tree refuse payment unless bring current call several time day fax personal info payment history work fax co workers see pay payment threats take home pay another call another payment tell still payment behind need pay would bring current explain receive another call minutes later another account rep handle account threaten would void payment day would put days past due ask speak manager get phone say look call back next day ask payment void tell pull statement see reverse back account refuse payment except tactics use right try keep home purposely refuse payment damage credit make loose home tell file foreclosure believe would want push customer foreclosure payment past due try keep home always pay time husband lose job proof except payment void believe play game talk several people claim managers say look follow',
#  u'sign e bill synchrony everything go fine change website sign userid passwords recognize call complain ask start send statements mail could get account new website call three time make request actually mail request also still receive statements constantly call leave message call real number meantime charge late charge n pay within certain time add interest want pay bill statement please help entity completely ruin credit',
#  u'able obtain refund amazon credit card jacket send back date credit issue second pair sticky sandal also return receipt jacket small line dog fur pay file custom declaration',
#  u'mortgage transfer loan incomplete file weeks unable make progress get insurance money complete project progress hobank phone',
#  u'send credit card solicitations address father die years ago call ask get information person speak n really answer send credit card solicitations dead person sound shady b open invitation fraud father good name company get information father like stop father sake others also get solicitations thank',
#  u'hello veteran unemployed time injuries military issue mortage holder forclosed loan account errors part apply force insurance amount account statements spread sheet already home insure thru state farm insurance agency would make payments mortage company would term send payments back would deny receive best make payments time hard lender threating forclosure notice back forward try resolve serious issue come favorable conclusing time think mortgage company fail follow appropriate bill account practice homeowners loan',
#  u'trouble payments handle loan split navient screw payments would send navient per address provide well payments send navient get credit account call say send proof send money load cancel check go online upload document tell options upload docs website call explain story time different reps keep pass buck around different reps finally rep tell place upload docs reps tell straight lie finally talk rep tell send separate payments different account number navient company shut customer service par different company umbrella',
#  u'periodically problems pay mortgage past time behind around months would call would return call transfer areas put hold noone actually answer call able pay flagstar refuse take payment make least payments time start mail payments use postal money order access account online totally disable flagstar longer able see activity acount saw message say mortgage sell another servicer new servicer would contact via letter three four months ago still hear anything nobody flagstar communicate first unpleasant incident originators mortgage purchase home interest rate mortgage high manageable notify wife take ill suggest modification tell least days past due eligible suggest paperwork lose submit hear nothing find mortgage sell another institution hold mortgage surprise actually home equity loan time go proceded try get mortgage hold modify comply request paperwork lose deem incomplete send additional copy one employees send email manager unprofessional remark attempt get modification yes inadvertently cc email respond manager displeasure content email manager immediately reply favorable reduction interest rate along change repayment term amortize years monthly payments fifteen years balloon payment end fifteen years loan amortize years pay entire loan time frame months since hear still idea loan',
#  u'corporation dissolve credit card issue corporation never sign personal guarantee lose business begin receive bill collection notice revolve account ask creditors provide proof personal responsibility corporation many months years correspondence still provide proof attorney correspond still receive evidence personal responsibility veteran old collection account affect credit keep lower interest rate',
#  u'recently send online secure message ask lower interest rate approve another much lower interest rate also inquire give low credit limit consider approve new low interest rate high credit limit refuse respond write respond via online secure message try get call ask matter escalate corporate office write response instead someone leave voicemail message call back legal right insist communications bank credit card company write via online secure message go online activate new card block receive account restrict message already warn would file regulatorydept complaint continue fail respond write restrict new account file complaint clearly act retaliation regulatorydept fail appropriately address matter instead simply send response consider matter close report congressman well post internet clearly indicate regulatorydept dummy agency create sole purpose keep occ handle consumer complaints',
#  u'regard business greentree service try make mortgage payment past two three weeks one company answer phone call company website wont take payment online originally make payment tell go call everyday since try make payment yet reach someone company contact number find relation payments one answer know else get close end month want report credit actually money make payment anything help would greatly appreciate',
#  u'pay card get statement pass due new bal min pymt',
#  u'may concernxxxx sell loan receive notification make regular payment never sign document anything advise nothing change fine payment go start call get kind assistance understand payments go per year response able get oh escrow disclosure statement show basically n feel need explain anything make least phone call one help make every single payments time see attach copy payment however show months behind credit shoot unable get supervisor help straighten manage reach someone seem want get resolve month actually correspond via email see attach refer supervisor yet contact email figure along copy check return back locations california unable go branch speak anyone send escrow statements period time quite confuse create statement confirm pay pay figure pay attach figure also forward wits end please help get resolve regard',
#  u'credit card financial difficulties get couple months behind card call make arrangements card pay months get catch give account info take money automatically card able pay full call make payments phone days later go online check account reflect new balance find note say account suspend call ask mean say could longer use account would remain open would still get yearly charge could use inform take money nearly would able use card anymore also check credit report days late never update balance zero still report old balance',
#  u'take reverse mortgage sell champion mortgage loan number borrower past away non borrow survive spouse try sell home champion send estate payoff demand due death borrower per term original loan believe months sale property plus extensions necessary send notice intent instruct champion along authorization trustee trust home initially list market sale owner talk champion receive denial letter acknowledge properly comply everything need file speak regard letter say request incomplete detail miss resolve indeed current document champion letter yet request per earlier conversation data speak champion regard letter date tell submit another extension request need property list realtor system accordingly expiration first extension send another extension request follow request second extension receive letter champion attorney date speak take direction champion sure transfer receive letter champion date deny extension request support document earlier tell could see list via send list agreement realtor receive notice default date copy nod attorney record today call champion get resolution extension refuse speak tell authority file send data request confirm several conversations guy bully try malign widow fha insure loan whereby additional risk',
#  u'almost impossible reach anyone phone never receive monthly statements mail one seem able get zip code right receive tax form somehow threaten letter however get ascertain payments due sloppy customer service',
#  u'contact discuss escrow account reach escrow division call via main number wait hear prompt press button still get basic customer service representative help spend three hobank hold last week week try success start email help customer service representative say could give number would connect escrow main number mortgage number take longer get prompt without help email back today say could help information give basically account number information plus complaint enough someone finally call escrow department also say record indicate representative already address concern gentleman give different phone number could n help escrow analyse tend hit high want discuss find last analysis also concern request form first think document scam many phone call tell send form letter connect request ask full social security number threaten monetary punishment mail back believe go garnish tax return ss bold letter could see return envelope truly think attempt steal id many phone call email claim validity document wrap complete form paper return envelope transparent full ss file would sign new form',
#  u'mortgage loan servicer repeatedly fail process mortgage modification request submit every request require document time frame manner request time deny request state submit request require document however false never identify document miss incomplete appeal use internal appeal process appeal deny denial letter appear form generate contain specifics information miss incomplete file notice default tell write numerous occassions wish resume payments bring loan current appear intentionally deceitfully deny mortgage modification request ground incomplete information reality intention process request good faith',
#  u'misguide close platinum card account say could still use membership reward days card close card close could longer redeem reward try reopen card use reward reject application reopen card cite credit reason feel treat unfairly cardholder years feel cheat reward advise close card stipulate could still access reward',
#  u'expire options mortgage company write letter help matter think mortgage company work good faith unethical practice fell behind mortgage last months try catch constant touch customer service department along loss mitigation department last month call customer department ask total payoff payoff loan however due financial hardships side able pay ask extension call talk customer service rep tell go pay past due amount send total pay amount try pay whole loan amount furthermore ask loan still current legal action assure rep red flag account go foreclosure good pay get letter third party collection agency loan transfer trustee sale call tell need call take case back call customer department transfer loss mitigation department explain tell customer rep tell customer rep good pay without legal action account however rude refuse help litigation department also tell charge extra plus late fee top third party collection fee try talk various reps department solve issue however meet rude reps refuse help even ask talk supervisor refuse first put voice mail name leave message however response days ask department send copy total payoff tell within hobank however never get anything call tell take days beg department send payoff remove legal charge longer wait payoff legal charge get accumulate however fail help address issue oh god rude today get payoff detail via email call bunch different reps get different answer one expire efforts solve matter customer service department especially loss litigation department write letter office help stop unethical practice charge extra legal fee clearly tell pay legal action take account reach help matter understand late payments make full effort bring account current status prove work good faith bring account current status put several call last couple months keep update progress side even tell accept late fee account since late pay payments however need remove legal charge since tell account red flag till pay legal charge third party charge around top charge',
#  u'former mortgage company buy green tree statements green tree month fix rate nothing else change go financial institutions mortgage specialist review disclosure statement green tree look though green tree raise pmi charge year approximately pmi mortgage last years feel dishonest charge furthermore mortgage specialist seem think legal tactic raise pmi much',
#  u'green tree service refuse apply additional fund principal balance despite website clearly indicate automatically apply fund',
#  u'problems customer service discuss unrelated business mater current lender make aware account authorize initiate list cosigner immediately notify lender victim identity fraud request see information file turn check credit report confirm presence fraudulent account contact credit report company dispute information vary date credit report company crcs report account confirm lender date fraudulent information remain credit file neither crc ever notate credit profile account dispute several additional telephonic request lender lender mail copy loan origination document along internal id theft package immediately file law enforcement report ler local sheriff office return original package support documentation lender support documentation include copy lender loan origination document ler drivers license social security card hand write sample notify potential employer deem unsuitable due presence delinquent financial information credit report notification provide copy combine credit report still contain fraudulent account crc report begin research laws learn fcra ftc learn combination ler ftc identity theft affidavit ita produce identity theft report idr file ita ftc website turn send via certify mail ftc crc template letter support documentation credit report company request fraudulent account block remove extend fraud alert place credit file per fcra support documentation submission ftc crc template letter include copy lender loan origination document credit report drivers license social security card hand write sample well fcra section accord track crcs receive certify letter respectively date crc place extend fraud alert block fraudulent account information respective credit profile contact decline request block fraudulent information fact crc allow order credit report directly advise via telephone idr sufficient would provide justification method make determination subsequently respectively order additional credit report indicate crc non compliance fcra impose time limit credit crcs list fraudulent account dispute investigation additionally send time via certify mail ftc lender template letter support documentation lender request lender block absolve responsibility stop inaccurately furnish fraudulent account information crcs support documentation submission ftc lender template letter include copy lender loan origination document id theft affidavit idr credit report drivers license social security card hand write sample well ftc notice furnishers accord track lender receive certify letter date lender make contact ftc ita',
#  u'loan green tree refinance loan lower rate refinance green tree ask authorization form release information sign form resubmit green tree since ask change verbage time authorization release information contact green tree representatives help idea send letter normal quick refinance money take weeks wait months gree tree idea company still buisness several issue green tree seek loan options buy exist loan green tree longer deal incompitence',
#  u'deny loan modification property purchase process beingsued preditory lend file bankrupcy month year nation star mortgage eventually gain control mortgage break chain title gt mortgage mers transfer mortgage gt freddie mac own mortgage gt please see attachment attorney havesubmitted complete information process loan modification review last foreclosure process move along final stag judiciary process feel act timely manner follow guidelines fair loan modification property reason mod denial delinquent amount due high produce lower mortgage amount increase steadily loan mod review take long regularly ask document find document need document time continue request new document resubmitted process would begin review request additional document would come time tick away review could notbe complete yet work diligently complete borrower packet qualify loan modification n feel work meet need timely fashion may follow correct guidelines loan modification behalf also seem illegal activity around account per documentation provide attachment attorney sale date certainly immanent property though give council matter currently attorney work legal aid hawaii hope stop foreclosure resources allow loan modification assistance without immediate attention matter likely foreclose property sale date post phone commissioner loan modification denial appeal review progress appeal loan mod denial deny today years old purchase property children grandchildren would like keep property possible thankyou',
#  u'green tree loan take loan find serious financial situation could n afford pay loan longer try short sell condo twice last attempt fail green tree demand bring additional money close pay sign paper basically say would still pay total loan amount loan get angry say green tree term legal short sell fell twice go green tree illegally obtain phone number previous employers handful family members green tree call every day day long tell people look owe money tell tell better pay green tree also ask everyone think right n pay phone call greatly affect life would receive phone call family members previous employers tell better get stuff figure green tree stop call almost lose job phone call work would n stop make several call green tree ask stop never file chapter get lawyer even right paperwork file green tree n stop several years later green tree pull credit every months send letter ask stop send letter back say right pull credit want green tree put make huge spectacle financial situation owe someone money give right abusive cbank e inform anyone ever know feel dead beat owe money threaten',
#  u'current mortgage mi month ago apply ohio refi lower rate shorter length request summit twice almost weeks still payoff send call yesterday tell would weeks could process payoff acceptable',
#  u'use credit card issue credit make purchase check credit card activity online realize pending charge purchase pending charge please see read little print even effect available credit pending ca pending ca recent activity may reflect pending fee charge transaction pending mean yet post account include current balance may impact available credit transaction post within hobank transactions amount may round next highest amountwhat happen never show balance credit card statement go pending show someone use credit short term free loan possible someone abuse credit get free fund thing happen husband purchase gas gas purchase non relate charge unknown company please see support documentation issue synchrony pbank uant license register trademark thank',
#  u'complaint regard poor reward system terrible structure policy company go credit card consumer least credit card various different company hand worst company ever deal even though meet spend requirement require pay balance wait next month close date point remain pending status well days process even fulfil requirement pay balance wait next close date point still unavailable never credit card take days receive point miles even though fulfil requirements literally worst credit card company ever nothing bad things rave never recommend friends family sure discontinue relationship one full year near fix reward system policies never use credit card company ever inconvenience lack flexability reward system never earn business experience credit card consumers',
#  u'stop foreclosure florida mortgage llc tx attention florida stop foreclosure florida case number write hop letter help stop foreclosure proceed home florida own home since due procedures fall behind payments due financial hardship hardship cause medical expense daily medication loss ability employ base hardship unable keep mortgage payments per month gainfully employ always attempt trustworthy good credit risk go recovery three hospital events attempt find create employ somehow health concern years old difficult hill climb would like avoid foreclosure commit stay home contact mortgage lender time past two years ask reasonable solution one response mortgage things progress foreclosure suit file court system stipulation go court order mediation process mediation hold mediation attend counsel florida mediation meet attempt solve come conclusion offer solution assistance mortgage represent attorney outcome would offer solution within days mediation meet days since commitment find solution contact office contact multiple e mail response several phone message leave responses send several e mail message response leave message response leave several message response leave several message response quite obvious make effort create solution base fact disregard court order solution mediation interim contact several help source solution response date home market attempt hang offer solution deed lue answer mail qualify try restructure mortgage send page require paperwork time base answer misplace lose fax paperwork would like work lender achieve solution however doubt consider also believe motive come work solution hope court offer consideration avoid complications price foreclosure would like remain home regain health find employment manage home ownership respectfully florida',
#  u'trouble payments handle loan originally consolidate loan fedloan account back last year confirm consolidation complete check send turn loan receieved tha payoff acount number work attempt resolve issue indicate get turnover fund indicate reach get return fund successful date afford pay loan need return fund pay',
#  u'go frontier airlines website purchase ticket upcoming trip website banner ad still state get air miles take frontier airlines mastercard barclay say must pay annual fee spend within days receive approval book card argue year receive air miles finally determine due air miles use card soon nothing site tell would appear intention site get take card may buy ticket problem would will bet people well false advertise predatory say least',
#  u'use credit card issue credit make purchase check credit card activity online realize pending charge purchase pending charge please see read little print even effect available credit pending ca pending ca recent activity may reflect pending fee charge transaction pending mean yet post account include current balance may impact available credit transaction post within hobank transactions amount may round next highest amountwhat happen never show balance credit card statement go pending show someone use credit short term free loan possible someone abuse credit get free fund thing happen husband purchase gas gas purchase non relate charge unknown company please see support documentation issue synchrony pbank uant license register trademark thank',
#  u'decrease monthly payments private student loan know navient stop attend college cause lack fund health issue start make payment loan high contact rate reduction department try get lower payment luck currently unemployed live michigan school age kid care receive social security due make difficult walk stand period time try get pay loan back try get lower payment month anyway help issue would appreciate much',
#  u'get call say potential fraud credit card immediately call back morning inform make charge say charge live credit card n use around years capital one fraud department say would liable charge since fraud ask want new card issue want account close ask account close transfer someone else help close account account close verify would responsible charge assure would would receive something mail show account close receive something show account close today receive bill charge specifically discuss today fraud team member speak today name least sound like inform way flag fraud post account inform charge restaurant already remove account insist explain charge never mention would even call ask fraud nothing go send bill anyway hang call back ask speak manager connect supervisor name apologize hang proceed confirm way process work remove charge post still confuse would call post mention need call back post order actually fix anything ice cake supervisor tell would connect someone else close account think wait already close account well turn n permanently close zero balance could n zero balance fraudulent charge remove beyond frustrate upset situation already felt violate someone steal information attempt charge things name want clear process n keep spend time emotion fix problem tell already fix',
# ...
#  u'write letter behalf lack concern underhanded tactics total disregard disrespect customers conduct unbecoming professionals whose job deal fairly justly customers face financial hardships regardless cause hardship file chapter bankruptcy attempt get handle debt receive letter green tree service llc inform loan transfer company would effect along new account number mail address bankruptcy discharge keep receive monthly bill statements pay tell still pay owe n could well lose home make decision see credit counselor try clean credit receive copy credit report green tree service llc appear outstanding balance request investigate correct account make payments green tree service llc amount dollars attempt speak green tree service llc concern matter give run around tell someone would contact one ever',
#  u'though multiple dispute private mortgate insurance pmi contact confirm payments pay time accurately find n pay pmi months ask refund never call back leave message phone number connect pmi group nobody answer phone company send letter confirm n need pay pmi would stop deduct still deduct statement stop continue ca n even reach company',
#  u'subject greentree service extend process evaluate document properly homeowner submit rma request modification result medical hardship file bankruptcy homeowner deny mha loan modification homeowner file require court document pay mortgage payment separately homeowner current medical hardship spouse homeowner aggravate medical hardship family member greentree fail take medical hardships account greentree begin double track set date foreclosure sale greentree violation doj department justice state attorney general settlement agreement homeowner discriminate form reverse discrimination age race medical hardships homeowner feel case unfairly treat follow reason active single point contact constantly change call make single point contact routine rout collection department never contact person single point contact assign homeowner think mortgage payment include trustee payment greentree inform homeowner modification options mha make home affordable guidelines homeowner authorize rd party make numerous call inquire status loan modification application call rout next available agent comment wrongfully advise document submit lostb document submit homeowner locate data base orc resubmit document foreclosure date set homeowner responsible provide request document point cause state confusion terror homeowners household greentree start double track procedure greentree aware loan modification process move forward double track anyway clear violation national mortgage settlement agreement specifically double track homeowner provide document good faith protect home foreclosure homeowner claim mortgage process discrimination delay process overload greentree process agents case work load case per one agent statement overload case cause form mortgage discrimination homeowners thus lose home inability loss mitigation department properly manage exist case load allege violations include limit follow fail perform proper loan modification process b fail manage process agents special point contact therefore cause process center unable handle homeowners case load form mortgage discrimination homeowners',
#  u'try refinance manufacture home last year mortgage company find first purchase home title never transfer name green tree finance company refuse produce title get title put name detitled refinance mortgage company refuse help process force hire attorney afford',
#  u'may concern within last years lose parent suffer receive gods grace recovery work month ago servicer sell loan greentree service receive documentation contact greentree tell bring note current qualify type modification contact mha make home affordable help hotline tell never receive modification eligible prepare document send greentree refuse confirm document post home foreclosure tuesday recently receive inheritance sale parent home also try request accurate pay greentree keep tell late anything except contact foreclosure attorney please help save home sincerely',
#  u'frustrate express customer service horrible open blue cash everyday credit card account weeks ago receive pre approval mail today blue cash everyday credit card better promotion offer cash back bonus instead bonus name home address mine call ask grant promotion mail receive since credit card account relatively new weeks old plus receive mail offer credit card product directly hour repeatedly explain wait due transfer around different departments agents several time get answer supervisor agent id basically say sorry bad luck even try contact express via social media ask twitter inform direct email contact regard concern anything extremely upset frustrate service understand advertise promotion offer grant point advertise send offer mail directly name address credit card product obtain exactly credit card product weeks ago tell way receive promotion ridiculous still physical copy advertise promotion mail receive keep action need thank much help',
#  u'able work green tree service mortgage payment since refinance green tree service stonewall attempt get gov program loan modification',
#  u'contact phh mortgage work due health issue tell worry could put program would give reduce interest rate help get back feet go doctor get medication back order able return work contact phh say would send package complete complete package send document brother call show package receive move loan foreclosure question tell lot snow past winter alone show enter package receive violation several laws service company require follow investigate think may delay equity property lose nothing lose everything brother try help get back either call every time promise help get list info need already give whole package document form still even submit program offer brother talk manager ask document already submit say recheck file get back list need check church write say get back get program post check days old days old get back lose almost could help damage credit could stop least foreclosure fee add loan road idea house get home lock kind pressure cause medical problem need help desperately ca n get mortgage company tell brother need want get program job money get payment ca n wo n give information several months payments want credit back time since ready since put foreclosure want contact brother get anything need think owe church old use think get program offer think waive foreclosure fee since could avoid act require think fix credit past months delay fix understand get behind fix problem ca n fix loan without help someone please call brother know understand break law next week someone please call tell need',
#  u'inc hold hardest hit fund months claim system issue',
#  u'mortgage originate mortgage sell loan green tree service months several issue apply payment incorrect account unable call make payment although normally get rep phone assist add next months payment statement month charge late fee pay follow month reputable wish give choice sure many struggle families frustrate please help',
#  u'decrease monthly payments student loan take agree upon month hardship agreement would pay monthly loan take navient honor agreement accord navient suppose honor agreements previously make clients navient claim appropriate information honor previous agreement however send information navient threaten take legal action make settlement base current income able make large settlement payment navient offer lower settlement option',
#  u'pay walmart store card balance full hold place account pattern payment still hold tell take days ask badge expect month tell certainly possible pattern payments',
#  u'apply loan modification year ago complete package three time send require document request mortgage company time three months process close modification miss document response email fax phone messagexxxx mail call put hold hobank say call back days year impossible get application system raise payment every six months raise payments loan current care',
#  u'keep get call loan private student loan navient mother cosigner loan negotiate navient reach payment amount actually afford today navient call husband cell work number leave message demand call turn loan debt collection husband list contact account clue would get contact info except maybe search seem like leave message regard loan violation privacy navient already call time per day addition today call mother husband',
#  u'refuse close premier reward gold card wife close card claim fee seemingly random amount accrue post close seek payment first ex stop send bill discover make payments pay card ask close indicate time complaint receive bill appear last couple months receive letter state card deactivate activate enclose new card want make charge activate new card sometime learn ex believe balance original card call inform annual fee assess repeat desire close account representative tell annual fee waive account close receive email indicate account close next receive letter indicate due account follow statement claim balance call ex first tell balance card stem charge tell ex information could correct pay balance since close account phone call tell balance stem charge work merchant recognize least possible place charge account error since account use previously however concern charge would accept close account transfer another ex employee claim owe account fourth sum quote call discontinue discussion next day call merchant indicate place charge ex account reverse bill separate account close ex account authorize new charge account refuse activate replacement card send response ex seek collect wildly variable amount money close account ask account correctly cod close pay full ask write confirmation status send zombie card need kill good possibility repeat return grave write communication could easily find enclose complaint',
#  u'pay credit card days due date due date receive bill state owe change make contact credit card company inform would take care tell would take business days see change account check account day amount double call credit card company ask speak w supervisor inform pay account prior due date tell would take care supervisor say make adjustments account speak inform would take business days see change wait check credit card account business days credit card company show balance n understand pay account accrue balance call call credit card company issue call fall deaf ears continue add fee account',
#  u'transfer home mortgage loan incorp want advise consumer financial protection bureau problem transfer mortgage one service provider another suffer huge economic harm transfer home mortgage effective record loan number ssn property sale buyer property sell property b c service loan accord record loan afraid lose sale property b c transfer loan effective loan number ssn system think regulatorydept require consumer always contact loan transfer loan complete new servicer information system consumer account completely set test happen last time loan transfer loan payments deposit receive notice days late mortgage eventually credit late fee believe never remove late payments credit score expect happen receive letter state mortgage transfer effective phone xxxxxxxxxxxx confirm rep advise mortgage fact transfer effective provide number contact loan call number listen script admit record loan call could speak person mortgage current b c record mortgage either loan number ssn record play first call follow recently receive welcome package recently transfer loan cont press enter loan press enter ssn enter ssn could n find ssn please enter ssn sorry could n find ssn please enter ssn recently receive welcome package notice new servicer mortgage loan please press otherwise please press allow better serve encourage visit web site time still receive information prior service provider unable speak loan detail soon set account send welcome package also try contact phone expect happen month n hear call back able help receive information prior servicer set account thank phone disconnect',
#  u'sign promotional sales home design store credit limit go ahead buy furniture store amount ask go two years promotional purchase say yes charge additional bring total expense interest pay within two years sudden charge interest fee additional late fee whereas inform neither take place debt pay within two years charge accrue interest time purchase',
#  u'wife separate since stay house inform move file bankruptcy mortgage months behind contact mortgage company discuss get account current first name give full name inform make consecutive payments would adjust account current conversation take place end state payment due end would first consecutive payments bring account current first payment would count payment later tell payment due end month another payment due next day careful insure would payment due days row insure case inform payment due first month tell retire pension deposit month fell weekend holiday might take days get state would nt problem week grace period account also tell wife file bankruptcy could n send paperwork verify agreement tell uncomfortable send large amount money without mortgage acknowledge payment adamant way could continue faith send monthly payments get statements call pay ments electronic transfer two months give payment amount different one give inquire nation star representative time tell database give number thing could process computer would n accept anything else phone payments pay representative tell pay receive foreclosure notice call immediately tell representative n get several payments copy statement make send call back next representative point payments late tell payments make phone representative direct pay amount tell discuss due date tell grace period allow payments arrive days late representative tell true trial period prove responsible enough handle account ask would turn family home discrepancy say yes person belligerent indicate recobank e point apply make home affordable loan send application package send duplicate copy entire package one e mail one fax receipt call back next week tell need documentation better narrative send call back next week tell receive tell document need form fill year need year fill form years need put years need original form leave tell must update form even though fill years need quit claim deed already send twice see close',
#  ...]

# %% [markdown]
# ## Feature Extraction for test data

# %% [markdown]
# #### Join the clean descriptions with the original data for creating features out of it

# %%
#Convert the clean_reviews list to dataframe
Tclean_reviews
Tclean_reviews_df = pd.DataFrame({'GrievanceDesc_clean':Tclean_reviews})
Tclean_reviews_df.shape
Tclean_reviews_df.head(2)

#Join the cleaned reviews with orignal data

frames = [Tclean_reviews_df, testdf1]
df2 = pd.concat(frames,axis=1)

df2=  df2[['GrievanceDesc_clean','GrievanceID','LineOfBusiness','ResolutionComments','Disputed']]
#df2.shape
#df2.head(1)
#df1
num_texts = df2['GrievanceDesc_clean'].size
num_texts
# Out:
# 24165

# %% [markdown]
# #### Import the BOW for creating features

# %%
BOWcorpus=pd.read_csv('BOW_NEW.csv')

# %%
#Import Pandas SQL library
from pandasql import *
import pandas as pd

# %% [markdown]
# #### Feature -> BusinessPractices

# %%
BOW = BOWcorpus[BOWcorpus["BusinessPractices"].notnull()]
BOW=BOW[["BusinessPractices"]]

num_keywords = BOW["BusinessPractices"].size
num_keywords

BOW = BOW.rename(columns={'BusinessPractices': 'list'})

pysqldf = lambda q: sqldf(q, globals())

q = """SELECT df2.*,BOW.* FROM df2 LEFT JOIN BOW ON df2.GrievanceDesc_clean LIKE '%' || BOW.list || '%'"""
df3 = pysqldf(q)

df3.loc[:, ['list']] = df3[['list']].notnull() * 1

df3.drop_duplicates(subset=None, keep='first', inplace=True)
df3 = df3.rename(columns={'list': 'BusinessPractices'})

print("Look at the distribution")
print(df3['BusinessPractices'].value_counts())

df3.reset_index()
df3=df3.reset_index(drop=True)
frames = [df2, df3['BusinessPractices']]
FeatureData = pd.concat(frames,axis=1)
# Out:
# Look at the distribution
# 0    17899
# 1     6266
# Name: BusinessPractices, dtype: int64

# %%
## Feature Communication

BOW = BOWcorpus[BOWcorpus["Communication"].notnull()]
BOW=BOW[["Communication"]]

num_keywords = BOW["Communication"].size
num_keywords

BOW = BOW.rename(columns={'Communication': 'list'})

pysqldf = lambda q: sqldf(q, globals())

q = """SELECT df2.*,BOW.* FROM df2 LEFT JOIN BOW ON df2.GrievanceDesc_clean LIKE '%' || BOW.list || '%'"""
df3 = pysqldf(q)

df3.loc[:, ['list']] = df3[['list']].notnull() * 1

df3.drop_duplicates(subset=None, keep='first', inplace=True)
df3 = df3.rename(columns={'list': 'Communication'})

print("Look at the distribution")
print(df3['Communication'].value_counts())

df3.reset_index()
df3=df3.reset_index(drop=True)
frames = [FeatureData, df3['Communication']]
df2 = pd.concat(frames,axis=1)
FeatureData = pd.concat(frames,axis=1)
# Out:
# Look at the distribution
# 1    14374
# 0     9791
# Name: Communication, dtype: int64

# %%
##CIBIL Score

BOW = BOWcorpus[BOWcorpus["CIBILScore"].notnull()]
BOW=BOW[["CIBILScore"]]

num_keywords = BOW["CIBILScore"].size
num_keywords

BOW = BOW.rename(columns={'CIBILScore': 'list'})

pysqldf = lambda q: sqldf(q, globals())

q = """SELECT df2.*,BOW.* FROM df2 LEFT JOIN BOW ON df2.GrievanceDesc_clean LIKE '%' || BOW.list || '%'"""
df3 = pysqldf(q)

df3.loc[:, ['list']] = df3[['list']].notnull() * 1

df3.drop_duplicates(subset=None, keep='first', inplace=True)
df3 = df3.rename(columns={'list': 'CIBILScore'})

print("Look at the distribution")
print(df3['CIBILScore'].value_counts())

df3.reset_index()
df3=df3.reset_index(drop=True)
frames = [FeatureData, df3['CIBILScore']]
df2 = pd.concat(frames,axis=1)

FeatureData = pd.concat(frames,axis=1)
# Out:
# Look at the distribution
# 0    19755
# 1     4410
# Name: CIBILScore, dtype: int64

# %%
##Late fee and interest charges

BOW = BOWcorpus[BOWcorpus["LateFeeInterestCharges"].notnull()]
BOW=BOW[["LateFeeInterestCharges"]]

num_keywords = BOW["LateFeeInterestCharges"].size
num_keywords

BOW = BOW.rename(columns={'LateFeeInterestCharges': 'list'})

pysqldf = lambda q: sqldf(q, globals())

q = """SELECT df2.*,BOW.* FROM df2 LEFT JOIN BOW ON df2.GrievanceDesc_clean LIKE '%' || BOW.list || '%'"""
df3 = pysqldf(q)

df3.loc[:, ['list']] = df3[['list']].notnull() * 1

df3.drop_duplicates(subset=None, keep='first', inplace=True)
df3 = df3.rename(columns={'list': 'LateFeeInterestCharges'})

print("Look at the distribution")
print(df3['LateFeeInterestCharges'].value_counts())

df3.reset_index()
df3=df3.reset_index(drop=True)
frames = [FeatureData, df3['LateFeeInterestCharges']]
df2 = pd.concat(frames,axis=1)
FeatureData = pd.concat(frames,axis=1)
# Out:
# Look at the distribution
# 0    16776
# 1     7389
# Name: LateFeeInterestCharges, dtype: int64

# %%
##Payments

BOW = BOWcorpus[BOWcorpus["Payments"].notnull()]
BOW=BOW[["Payments"]]

num_keywords = BOW["Payments"].size
num_keywords

BOW = BOW.rename(columns={'Payments': 'list'})

pysqldf = lambda q: sqldf(q, globals())

q = """SELECT df2.*,BOW.* FROM df2 LEFT JOIN BOW ON df2.GrievanceDesc_clean LIKE '%' || BOW.list || '%'"""
df3 = pysqldf(q)

df3.loc[:, ['list']] = df3[['list']].notnull() * 1

df3.drop_duplicates(subset=None, keep='first', inplace=True)
df3 = df3.rename(columns={'list': 'Payments'})

print("Look at the distribution")
print(df3['Payments'].value_counts())

df3.reset_index()
df3=df3.reset_index(drop=True)
frames = [FeatureData, df3['Payments']]
df2 = pd.concat(frames,axis=1)
FeatureData = pd.concat(frames,axis=1)
# Out:
# Look at the distribution
# 0    16045
# 1     8120
# Name: Payments, dtype: int64

# %%
##Close and Cancel
BOW = BOWcorpus[BOWcorpus["CloseCancel"].notnull()]
BOW=BOW[["CloseCancel"]]

num_keywords = BOW["CloseCancel"].size
num_keywords

BOW = BOW.rename(columns={'CloseCancel': 'list'})

pysqldf = lambda q: sqldf(q, globals())

q = """SELECT df2.*,BOW.* FROM df2 LEFT JOIN BOW ON df2.GrievanceDesc_clean LIKE '%' || BOW.list || '%'"""
df3 = pysqldf(q)

df3.loc[:, ['list']] = df3[['list']].notnull() * 1

df3.drop_duplicates(subset=None, keep='first', inplace=True)
df3 = df3.rename(columns={'list': 'CloseCancel'})

print("Look at the distribution")
print(df3['CloseCancel'].value_counts())

df3.reset_index()
df3=df3.reset_index(drop=True)
frames = [FeatureData, df3['CloseCancel']]
df2 = pd.concat(frames,axis=1)
FeatureData = pd.concat(frames,axis=1)
# Out:
# Look at the distribution
# 0    18151
# 1     6014
# Name: CloseCancel, dtype: int64

# %%
##Purchase
BOW = BOWcorpus[BOWcorpus["purchase"].notnull()]
BOW=BOW[["purchase"]]

num_keywords = BOW["purchase"].size
num_keywords

BOW = BOW.rename(columns={'purchase': 'list'})

pysqldf = lambda q: sqldf(q, globals())

q = """SELECT df2.*,BOW.* FROM df2 LEFT JOIN BOW ON df2.GrievanceDesc_clean LIKE '%' || BOW.list || '%'"""
df3 = pysqldf(q)

df3.loc[:, ['list']] = df3[['list']].notnull() * 1

df3.drop_duplicates(subset=None, keep='first', inplace=True)
df3 = df3.rename(columns={'list': 'purchase'})

print("Look at the distribution")
print(df3['purchase'].value_counts())

df3.reset_index()
df3=df3.reset_index(drop=True)
frames = [FeatureData, df3['purchase']]
df2 = pd.concat(frames,axis=1)
FeatureData = pd.concat(frames,axis=1)
# Out:
# Look at the distribution
# 0    21674
# 1     2491
# Name: purchase, dtype: int64

# %%
##Delay or reccur

BOW = BOWcorpus[BOWcorpus["DelayRecur"].notnull()]
BOW=BOW[["DelayRecur"]]

num_keywords = BOW["DelayRecur"].size
num_keywords

BOW = BOW.rename(columns={'DelayRecur': 'list'})

pysqldf = lambda q: sqldf(q, globals())

q = """SELECT df2.*,BOW.* FROM df2 LEFT JOIN BOW ON df2.GrievanceDesc_clean LIKE '%' || BOW.list || '%'"""
df3 = pysqldf(q)

df3.loc[:, ['list']] = df3[['list']].notnull() * 1

df3.drop_duplicates(subset=None, keep='first', inplace=True)
df3 = df3.rename(columns={'list': 'DelayRecur'})

print("Look at the distribution")
print(df3['DelayRecur'].value_counts())

df3.reset_index()
df3=df3.reset_index(drop=True)
frames = [FeatureData, df3['DelayRecur']]
df2 = pd.concat(frames,axis=1)
FeatureData = pd.concat(frames,axis=1)
# Out:
# Look at the distribution
# 1    16999
# 0     7166
# Name: DelayRecur, dtype: int64

# %%
##Legal
BOW = BOWcorpus[BOWcorpus["legal"].notnull()]
BOW=BOW[["legal"]]

num_keywords = BOW["legal"].size
num_keywords

BOW = BOW.rename(columns={'legal': 'list'})

pysqldf = lambda q: sqldf(q, globals())

q = """SELECT df2.*,BOW.* FROM df2 LEFT JOIN BOW ON df2.GrievanceDesc_clean LIKE '%' || BOW.list || '%'"""
df3 = pysqldf(q)

df3.loc[:, ['list']] = df3[['list']].notnull() * 1

df3.drop_duplicates(subset=None, keep='first', inplace=True)
df3 = df3.rename(columns={'list': 'legal'})

print("Look at the distribution")
print(df3['legal'].value_counts())

df3.reset_index()
df3=df3.reset_index(drop=True)
frames = [FeatureData, df3['legal']]
df2 = pd.concat(frames,axis=1)
FeatureData = pd.concat(frames,axis=1)
# Out:
# Look at the distribution
# 0    15256
# 1     8909
# Name: legal, dtype: int64

# %%
##Mktng and Offer

BOW = BOWcorpus[BOWcorpus["Mkting_Offer_Reward"].notnull()]
BOW=BOW[["Mkting_Offer_Reward"]]

num_keywords = BOW["Mkting_Offer_Reward"].size
num_keywords

BOW = BOW.rename(columns={'Mkting_Offer_Reward': 'list'})

pysqldf = lambda q: sqldf(q, globals())

q = """SELECT df2.*,BOW.* FROM df2 LEFT JOIN BOW ON df2.GrievanceDesc_clean LIKE '%' || BOW.list || '%'"""
df3 = pysqldf(q)

df3.loc[:, ['list']] = df3[['list']].notnull() * 1

df3.drop_duplicates(subset=None, keep='first', inplace=True)
df3 = df3.rename(columns={'list': 'Mkting_Offer_Reward'})

print("Look at the distribution")
print(df3['Mkting_Offer_Reward'].value_counts())

df3.reset_index()
df3=df3.reset_index(drop=True)
frames = [FeatureData, df3['Mkting_Offer_Reward']]
df2 = pd.concat(frames,axis=1)
FeatureData = pd.concat(frames,axis=1)
# Out:
# Look at the distribution
# 0    19337
# 1     4828
# Name: Mkting_Offer_Reward, dtype: int64

# %%
##Payments

BOW = BOWcorpus[BOWcorpus["PaymentIssue"].notnull()]
BOW=BOW[["PaymentIssue"]]

num_keywords = BOW["PaymentIssue"].size
num_keywords

BOW = BOW.rename(columns={'PaymentIssue': 'list'})

pysqldf = lambda q: sqldf(q, globals())

q = """SELECT df2.*,BOW.* FROM df2 LEFT JOIN BOW ON df2.GrievanceDesc_clean LIKE '%' || BOW.list || '%'"""
df3 = pysqldf(q)

df3.loc[:, ['list']] = df3[['list']].notnull() * 1

df3.drop_duplicates(subset=None, keep='first', inplace=True)
df3 = df3.rename(columns={'list': 'PaymentIssue'})

print("Look at the distribution")
print(df3['PaymentIssue'].value_counts())

df3.reset_index()
df3=df3.reset_index(drop=True)
frames = [FeatureData, df3['PaymentIssue']]
df2 = pd.concat(frames,axis=1)
FeatureData = pd.concat(frames,axis=1)
# Out:
# Look at the distribution
# 1    15813
# 0     8352
# Name: PaymentIssue, dtype: int64

# %%
##Mortgage

BOW = BOWcorpus[BOWcorpus["MortgageBroadly"].notnull()]
BOW=BOW[["MortgageBroadly"]]

num_keywords = BOW["MortgageBroadly"].size
num_keywords

BOW = BOW.rename(columns={'MortgageBroadly': 'list'})

pysqldf = lambda q: sqldf(q, globals())

q = """SELECT df2.*,BOW.* FROM df2 LEFT JOIN BOW ON df2.GrievanceDesc_clean LIKE '%' || BOW.list || '%'"""
df3 = pysqldf(q)

df3.loc[:, ['list']] = df3[['list']].notnull() * 1

df3.drop_duplicates(subset=None, keep='first', inplace=True)
df3 = df3.rename(columns={'list': 'MortgageBroadly'})

print("Look at the distribution")
print(df3['MortgageBroadly'].value_counts())

df3.reset_index()
df3=df3.reset_index(drop=True)
frames = [FeatureData, df3['MortgageBroadly']]
df2 = pd.concat(frames,axis=1)
FeatureData = pd.concat(frames,axis=1)
# Out:
# Look at the distribution
# 0    16085
# 1     8080
# Name: MortgageBroadly, dtype: int64

# %%
##Theft n Fraud

BOW = BOWcorpus[BOWcorpus["TeftFraudThreat"].notnull()]
BOW=BOW[["TeftFraudThreat"]]

num_keywords = BOW["TeftFraudThreat"].size
num_keywords

BOW = BOW.rename(columns={'TeftFraudThreat': 'list'})

pysqldf = lambda q: sqldf(q, globals())

q = """SELECT df2.*,BOW.* FROM df2 LEFT JOIN BOW ON df2.GrievanceDesc_clean LIKE '%' || BOW.list || '%'"""
df3 = pysqldf(q)

df3.loc[:, ['list']] = df3[['list']].notnull() * 1

df3.drop_duplicates(subset=None, keep='first', inplace=True)
df3 = df3.rename(columns={'list': 'TeftFraudThreat'})

print("Look at the distribution")
print(df3['TeftFraudThreat'].value_counts())

df3.reset_index()
df3=df3.reset_index(drop=True)
frames = [FeatureData, df3['TeftFraudThreat']]
df2 = pd.concat(frames,axis=1)
FeatureData = pd.concat(frames,axis=1)
# Out:
# Look at the distribution
# 0    20705
# 1     3460
# Name: TeftFraudThreat, dtype: int64

# %%
## UFDP

BOW = BOWcorpus[BOWcorpus["UFDP"].notnull()]
BOW=BOW[["UFDP"]]

num_keywords = BOW["UFDP"].size
num_keywords

BOW = BOW.rename(columns={'UFDP': 'list'})

pysqldf = lambda q: sqldf(q, globals())

q = """SELECT df2.*,BOW.* FROM df2 LEFT JOIN BOW ON df2.GrievanceDesc_clean LIKE '%' || BOW.list || '%'"""
df3 = pysqldf(q)

df3.loc[:, ['list']] = df3[['list']].notnull() * 1

df3.drop_duplicates(subset=None, keep='first', inplace=True)
df3 = df3.rename(columns={'list': 'UFDP'})

print("Look at the distribution")
print(df3['UFDP'].value_counts())

df3.reset_index()
df3=df3.reset_index(drop=True)
frames = [FeatureData, df3['UFDP']]
df2 = pd.concat(frames,axis=1)
FeatureData = pd.concat(frames,axis=1)
# Out:
# Look at the distribution
# 1    13331
# 0    10834
# Name: UFDP, dtype: int64

# %%
##Final prepared data at grievance level -test
Add_data=  testdf1[['BankID','State','DateOfGrievance','Grievance_Category','DateOfResolution']]
frames = [FeatureData, Add_data]
FinalGrievanceDt = pd.concat(frames,axis=1)

# %%
FinalGrievanceDt.shape
# Out:
# (24165, 24)

# %%
#Derive days to resolve

FinalGrievanceDt['Daystoresolve']=((pd.to_datetime(FinalGrievanceDt['DateOfResolution']))-(pd.to_datetime(FinalGrievanceDt['DateOfGrievance']))).dt.days

# %%
#### Creating 5 additional features flags for top 5 (highest grievance issues) states

FinalGrievanceDt['State9'] = np.where(FinalGrievanceDt['State']=='State9', 1, 0)
FinalGrievanceDt['State14'] = np.where(FinalGrievanceDt['State']=='State14', 1, 0)
FinalGrievanceDt['State43'] = np.where(FinalGrievanceDt['State']=='State43', 1, 0)
FinalGrievanceDt['State53'] = np.where(FinalGrievanceDt['State']=='State53', 1, 0)
FinalGrievanceDt['State47'] = np.where(FinalGrievanceDt['State']=='State47', 1, 0)

# %%
#### Creating 2 variables using line of business for mortgage and credit cards

FinalGrievanceDt['Mortgage'] = np.where(FinalGrievanceDt['LineOfBusiness']=='Mortgage', 1, 0)
FinalGrievanceDt['CreditCard'] = np.where(FinalGrievanceDt['LineOfBusiness']=='Credit card', 1, 0)

# %%
#### Creating 4 additional variables for days to resolve 
FinalGrievanceDt['DaystoResolveflg']='NA'
FinalGrievanceDt['DaystoResolveflg'][(FinalGrievanceDt['Daystoresolve'] <= 30)] = '1Monthorless'
FinalGrievanceDt['DaystoResolveflg'][(FinalGrievanceDt['Daystoresolve'] > 30) & (FinalGrievanceDt['Daystoresolve'] <= 60)] = '1to2Months'
FinalGrievanceDt['DaystoResolveflg'][(FinalGrievanceDt['Daystoresolve'] > 60) & (FinalGrievanceDt['Daystoresolve'] <= 90)] = '2to3Months'
FinalGrievanceDt['DaystoResolveflg'][(FinalGrievanceDt['Daystoresolve'] > 90)] = '3Monthsormore'

FinalGrievanceDt['Lessthan1Month'] = np.where(FinalGrievanceDt['DaystoResolveflg']=='1Monthorless', 1, 0)
FinalGrievanceDt['1to2Months'] = np.where(FinalGrievanceDt['DaystoResolveflg']=='1to2Months', 1, 0)
FinalGrievanceDt['2to3Months'] = np.where(FinalGrievanceDt['DaystoResolveflg']=='2to3Months', 1, 0)
FinalGrievanceDt['3Monthsormore'] = np.where(FinalGrievanceDt['DaystoResolveflg']=='3Monthsormore', 1, 0)
# Out:
# /anaconda2/lib/python2.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# /anaconda2/lib/python2.7/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.
# /anaconda2/lib/python2.7/site-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """
# /anaconda2/lib/python2.7/site-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
#### Create 1 additional variable for closed with explanation grievances 

FinalGrievanceDt['ClosedwithExplain'] = np.where(FinalGrievanceDt['ResolutionComments']=='Closed with explanation', 1, 0)

# %%
#### Creating 4 additional variables for days to resolve 

FinalGrievanceDt['ClosedwithExplain_Dispute'] = np.where((FinalGrievanceDt['ResolutionComments']=='Closed with explanation') & (FinalGrievanceDt['Disputed']=='Yes'), 1, 0)

# %%
#### Create 1 additional variable for closed with explanation grievances 
FinalGrievanceDt['ClosedwithExplain_Dispute_Commu'] = np.where((FinalGrievanceDt['ResolutionComments']=='Closed with explanation') & (FinalGrievanceDt['Disputed']=='Yes') & (FinalGrievanceDt['Communication']==1), 1, 0)

# %%
FinalGrievanceDt.shape
# Out:
# (24165, 40)

# %%
#Save the data to pickle
#FinalGrievanceDt.to_pickle('TestFinalGrievanceDt_Saved.pkl') 
FinalGrievanceDt = pd.read_pickle('TestFinalGrievanceDt_Saved.pkl')

# %%
##Data Role up at bank level

# %%
State9 = FinalGrievanceDt[['BankID','State9']].groupby(['BankID'])['State9'].sum().reset_index(name='State9_sum')
State14 = FinalGrievanceDt[['BankID','State14']].groupby(['BankID'])['State14'].sum().reset_index(name='State14_sum')
State43 = FinalGrievanceDt[['BankID','State43']].groupby(['BankID'])['State43'].sum().reset_index(name='State43_sum')
State53 = FinalGrievanceDt[['BankID','State53']].groupby(['BankID'])['State53'].sum().reset_index(name='State53_sum')
State47 = FinalGrievanceDt[['BankID','State47']].groupby(['BankID'])['State47'].sum().reset_index(name='State47_sum')
BusinessPractices = FinalGrievanceDt[['BankID','BusinessPractices']].groupby(['BankID'])['BusinessPractices'].sum().reset_index(name='BusinessPract_Sum')
Communication = FinalGrievanceDt[['BankID','Communication']].groupby(['BankID'])['Communication'].sum().reset_index(name='Communicn_Sum')
CIBILScore = FinalGrievanceDt[['BankID','CIBILScore']].groupby(['BankID'])['CIBILScore'].sum().reset_index(name='CIBILScore_Sum')
LateFeeInterestCharges = FinalGrievanceDt[['BankID','LateFeeInterestCharges']].groupby(['BankID'])['LateFeeInterestCharges'].sum().reset_index(name='LateFeeIntCharg_Sum')
CloseCancel = FinalGrievanceDt[['BankID','CloseCancel']].groupby(['BankID'])['CloseCancel'].sum().reset_index(name='CloseCancel_Sum')
purchase = FinalGrievanceDt[['BankID','purchase']].groupby(['BankID'])['purchase'].sum().reset_index(name='purchaser_Sum')
DelayRecur = FinalGrievanceDt[['BankID','DelayRecur']].groupby(['BankID'])['DelayRecur'].sum().reset_index(name='DelayRecur_Sum')
legal = FinalGrievanceDt[['BankID','legal']].groupby(['BankID'])['legal'].sum().reset_index(name='legal_Sum')
Mkting_Offer_Reward = FinalGrievanceDt[['BankID','Mkting_Offer_Reward']].groupby(['BankID'])['Mkting_Offer_Reward'].sum().reset_index(name='MktOfferRwd_Sum')
PaymentIssue = FinalGrievanceDt[['BankID','PaymentIssue']].groupby(['BankID'])['PaymentIssue'].sum().reset_index(name='PaymentIssue_Sum')
MortgageBroadly = FinalGrievanceDt[['BankID','MortgageBroadly']].groupby(['BankID'])['MortgageBroadly'].sum().reset_index(name='MortgageBroad_Sum')
TeftFraudThreat = FinalGrievanceDt[['BankID','TeftFraudThreat']].groupby(['BankID'])['TeftFraudThreat'].sum().reset_index(name='TeftFraudThreat_Sum')
Mortgage = FinalGrievanceDt[['BankID','Mortgage']].groupby(['BankID'])['Mortgage'].sum().reset_index(name='Mortgage_Sum')
CreditCard = FinalGrievanceDt[['BankID','CreditCard']].groupby(['BankID'])['CreditCard'].sum().reset_index(name='CreditCard_Sum')
Lessthan1Month = FinalGrievanceDt[['BankID','Lessthan1Month']].groupby(['BankID'])['Lessthan1Month'].sum().reset_index(name='Lessthan1Month_Sum')
OnetotwoMonths = FinalGrievanceDt[['BankID','1to2Months']].groupby(['BankID'])['1to2Months'].sum().reset_index(name='1to2Months_Sum')
twotothreeMonths = FinalGrievanceDt[['BankID','2to3Months']].groupby(['BankID'])['2to3Months'].sum().reset_index(name='2to3Months_Sum')
More3months = FinalGrievanceDt[['BankID','3Monthsormore']].groupby(['BankID'])['3Monthsormore'].sum().reset_index(name='3Monthsormore_Sum')
ClosExpl = FinalGrievanceDt[['BankID','ClosedwithExplain']].groupby(['BankID'])['ClosedwithExplain'].sum().reset_index(name='ClosExpl_Sum')
ClosExplDisp = FinalGrievanceDt[['BankID','ClosedwithExplain_Dispute']].groupby(['BankID'])['ClosedwithExplain_Dispute'].sum().reset_index(name='ClosExplDisp_Sum')
ClosExplDispCom = FinalGrievanceDt[['BankID','ClosedwithExplain_Dispute_Commu']].groupby(['BankID'])['ClosedwithExplain_Dispute_Commu'].sum().reset_index(name='ClosExplDispCom_Sum')
CntGriev = FinalGrievanceDt[['BankID','GrievanceID']].groupby(['BankID'])['GrievanceID'].count().reset_index(name='Cnt_Griev')
AvgdaystoRes = FinalGrievanceDt[['BankID','Daystoresolve']].groupby(['BankID'])['Daystoresolve'].mean().reset_index(name='AvgdaystoResolve')
MeddaystoRes = FinalGrievanceDt[['BankID','Daystoresolve']].groupby(['BankID'])['Daystoresolve'].median().reset_index(name='MediandaystoResolve')
Payments = FinalGrievanceDt[['BankID','Payments']].groupby(['BankID'])['Payments'].sum().reset_index(name='Payments_Sum')
UFDP = FinalGrievanceDt[['BankID','UFDP']].groupby(['BankID'])['UFDP'].sum().reset_index(name='UFDP_Sum')

# %%
State9.set_index("BankID",drop=True,inplace=True)
State14.set_index("BankID",drop=True,inplace=True)
State43.set_index("BankID",drop=True,inplace=True)
State53.set_index("BankID",drop=True,inplace=True)
State47.set_index("BankID",drop=True,inplace=True)
BusinessPractices.set_index("BankID",drop=True,inplace=True)
Communication.set_index("BankID",drop=True,inplace=True)
CIBILScore.set_index("BankID",drop=True,inplace=True)
LateFeeInterestCharges.set_index("BankID",drop=True,inplace=True)
CloseCancel.set_index("BankID",drop=True,inplace=True)
purchase.set_index("BankID",drop=True,inplace=True)
DelayRecur.set_index("BankID",drop=True,inplace=True)
legal.set_index("BankID",drop=True,inplace=True)
Mkting_Offer_Reward.set_index("BankID",drop=True,inplace=True)
PaymentIssue.set_index("BankID",drop=True,inplace=True)
MortgageBroadly.set_index("BankID",drop=True,inplace=True)
TeftFraudThreat.set_index("BankID",drop=True,inplace=True)
Mortgage.set_index("BankID",drop=True,inplace=True)
CreditCard.set_index("BankID",drop=True,inplace=True)
Lessthan1Month.set_index("BankID",drop=True,inplace=True)
OnetotwoMonths.set_index("BankID",drop=True,inplace=True)
twotothreeMonths.set_index("BankID",drop=True,inplace=True)
More3months.set_index("BankID",drop=True,inplace=True)
ClosExpl.set_index("BankID",drop=True,inplace=True)
ClosExplDisp.set_index("BankID",drop=True,inplace=True)
ClosExplDispCom.set_index("BankID",drop=True,inplace=True)
CntGriev.set_index("BankID",drop=True,inplace=True)
AvgdaystoRes.set_index("BankID",drop=True,inplace=True)
MeddaystoRes.set_index("BankID",drop=True,inplace=True)
Payments.set_index("BankID",drop=True,inplace=True)
UFDP.set_index("BankID",drop=True,inplace=True)

# %%
## 1) Import Bank level Target variable
BankID=pd.read_csv('BankTestID.csv')

# %%
frames = [State9,State14,State43,State53,State47,BusinessPractices,Communication,CIBILScore,LateFeeInterestCharges,CloseCancel,purchase,DelayRecur,legal,Mkting_Offer_Reward,PaymentIssue,MortgageBroadly,TeftFraudThreat,Mortgage,CreditCard,Lessthan1Month,OnetotwoMonths,twotothreeMonths,More3months,ClosExpl,ClosExplDisp,ClosExplDispCom,CntGriev,AvgdaystoRes,MeddaystoRes,Payments,UFDP]
Bankleveldata= pd.concat(frames,axis=1)

FinalBankleveldata = pd.merge(Bankleveldata, BankID, how='inner', on=['BankID'])

# %%
FinalBankleveldata['State9_pct'] = ((FinalBankleveldata['State9_sum']/FinalBankleveldata['Cnt_Griev'])*100).round(2)
FinalBankleveldata['State14_pct'] = ((FinalBankleveldata['State14_sum']/FinalBankleveldata['Cnt_Griev'])*100).round(2)
FinalBankleveldata['State43_pct'] = ((FinalBankleveldata['State43_sum']/FinalBankleveldata['Cnt_Griev'])*100).round(2)
FinalBankleveldata['State53_pct'] = ((FinalBankleveldata['State53_sum']/FinalBankleveldata['Cnt_Griev'])*100).round(2)
FinalBankleveldata['State47_pct'] = ((FinalBankleveldata['State47_sum']/FinalBankleveldata['Cnt_Griev'])*100).round(2)            
FinalBankleveldata['BusinessPract_pct'] = ((FinalBankleveldata['BusinessPract_Sum']/FinalBankleveldata['Cnt_Griev'])*100).round(2)
FinalBankleveldata['Communicn_pct'] = ((FinalBankleveldata['Communicn_Sum']/FinalBankleveldata['Cnt_Griev'])*100).round(2)
FinalBankleveldata['LateFeeIntCharg_pct'] = ((FinalBankleveldata['LateFeeIntCharg_Sum']/FinalBankleveldata['Cnt_Griev'])*100).round(2)                  
FinalBankleveldata['CIBILScore_pct'] = ((FinalBankleveldata['CIBILScore_Sum']/FinalBankleveldata['Cnt_Griev'])*100).round(2)
FinalBankleveldata['CloseCancel_pct'] = ((FinalBankleveldata['CloseCancel_Sum']/FinalBankleveldata['Cnt_Griev'])*100).round(2)
FinalBankleveldata['purchaser_pct'] = ((FinalBankleveldata['purchaser_Sum']/FinalBankleveldata['Cnt_Griev'])*100).round(2)
FinalBankleveldata['DelayRecur_pct'] = ((FinalBankleveldata['DelayRecur_Sum']/FinalBankleveldata['Cnt_Griev'])*100).round(2)
FinalBankleveldata['legal_pct'] = ((FinalBankleveldata['legal_Sum']/FinalBankleveldata['Cnt_Griev'])*100).round(2)
FinalBankleveldata['MktOfferRwd_pct'] = ((FinalBankleveldata['MktOfferRwd_Sum']/FinalBankleveldata['Cnt_Griev'])*100).round(2)                      
FinalBankleveldata['PaymentIssue_pct'] = ((FinalBankleveldata['PaymentIssue_Sum']/FinalBankleveldata['Cnt_Griev'])*100).round(2)
FinalBankleveldata['MortgageBroad_pct'] = ((FinalBankleveldata['MortgageBroad_Sum']/FinalBankleveldata['Cnt_Griev'])*100).round(2)        
FinalBankleveldata['TeftFraudThreat_pct'] = ((FinalBankleveldata['TeftFraudThreat_Sum']/FinalBankleveldata['Cnt_Griev'])*100).round(2)    
FinalBankleveldata['Mortgage_pct'] = ((FinalBankleveldata['Mortgage_Sum']/FinalBankleveldata['Cnt_Griev'])*100).round(2)                                    
FinalBankleveldata['CreditCard_pct'] = ((FinalBankleveldata['CreditCard_Sum']/FinalBankleveldata['Cnt_Griev'])*100).round(2)                                    
FinalBankleveldata['Lessthan1Month_pct'] = ((FinalBankleveldata['Lessthan1Month_Sum']/FinalBankleveldata['Cnt_Griev'])*100).round(2)                                    
FinalBankleveldata['onetotwoMonths_pct'] = ((FinalBankleveldata['1to2Months_Sum']/FinalBankleveldata['Cnt_Griev'])*100).round(2)                                    
FinalBankleveldata['twotothreeMonths_pct'] = ((FinalBankleveldata['2to3Months_Sum']/FinalBankleveldata['Cnt_Griev'])*100).round(2)                                    
FinalBankleveldata['threeormoreMonths_pct'] = ((FinalBankleveldata['3Monthsormore_Sum']/FinalBankleveldata['Cnt_Griev'])*100).round(2)                                    
FinalBankleveldata['ClosExpl_pct'] = ((FinalBankleveldata['ClosExpl_Sum']/FinalBankleveldata['Cnt_Griev'])*100).round(2)                                    
FinalBankleveldata['ClosExplDisp_pct'] = ((FinalBankleveldata['ClosExplDisp_Sum']/FinalBankleveldata['Cnt_Griev'])*100).round(2)                                    
FinalBankleveldata['ClosExplDispCom_pct'] = ((FinalBankleveldata['ClosExplDispCom_Sum']/FinalBankleveldata['Cnt_Griev'])*100).round(2)    
FinalBankleveldata['Payments_pct'] = ((FinalBankleveldata['Payments_Sum']/FinalBankleveldata['Cnt_Griev'])*100).round(2)          
FinalBankleveldata['UFDP_pct'] = ((FinalBankleveldata['UFDP_Sum']/FinalBankleveldata['Cnt_Griev'])*100).round(2)

# %%
##Final Test data
FnllBanklvldata_Tgt= FinalBankleveldata.loc[:,['BankID','AvgdaystoResolve','MediandaystoResolve','State9_pct','State14_pct','State43_pct','State53_pct','State47_pct','BusinessPract_pct','Communicn_pct','LateFeeIntCharg_pct','CIBILScore_pct','CloseCancel_pct','purchaser_pct','DelayRecur_pct','legal_pct','MktOfferRwd_pct','PaymentIssue_pct','MortgageBroad_pct','TeftFraudThreat_pct','Mortgage_pct','CreditCard_pct','Lessthan1Month_pct','onetotwoMonths_pct','twotothreeMonths_pct','threeormoreMonths_pct','ClosExpl_pct','ClosExplDisp_pct','ClosExplDispCom_pct','Payments_pct','UFDP_pct']]

# %%
FnllBanklvldata_Tgt.shape
# Out:
# (22, 31)

# %%
#Save the final bank level aggregated data to pickle

#FnllBanklvldata_Tgt.to_pickle('TestFnllBanklvldata_Tgt_Saved.pkl') 
FnllBanklvldata_Tgt = pd.read_pickle('TestFnllBanklvldata_Tgt_Saved.pkl')

# %%
FnllBanklvldata_Tgt.describe()
# Out:
#        AvgdaystoResolve  MediandaystoResolve  State9_pct  State14_pct  \
# count         22.000000            22.000000   22.000000    22.000000
# mean          17.763099            13.613636   14.854091     9.196364
# std            3.475868             5.126801    7.645566     3.661246
# min           14.266010            11.000000    0.000000     2.200000
# 25%           15.659107            11.000000   11.572500     7.602500
# 50%           17.113172            11.000000   13.710000     8.510000
# 75%           18.333681            13.750000   17.022500    10.120000
# max           29.063291            31.000000   31.650000    17.950000
#
#        State43_pct  State53_pct  State47_pct  BusinessPract_pct  \
# count    22.000000    22.000000    22.000000          22.000000
# mean      6.235455     7.064091     4.739091          20.985000
# std       3.417582     4.340198     3.973244           7.382058
# min       0.000000     1.100000     0.920000           8.000000
# 25%       4.332500     3.497500     2.825000          17.135000
# 50%       5.665000     6.880000     3.945000          20.510000
# 75%       8.297500     9.730000     4.967500          25.452500
# max      13.190000    16.340000    19.780000          36.020000
#
#        Communicn_pct  LateFeeIntCharg_pct    ...      CreditCard_pct  \
# count      22.000000            22.000000    ...           22.000000
# mean       62.080909            26.646364    ...           31.109545
# std         8.370914             8.425706    ...           43.370517
# min        43.330000             3.330000    ...            0.000000
# 25%        57.665000            25.487500    ...            0.000000
# 50%        64.850000            29.235000    ...            0.000000
# 75%        66.657500            31.462500    ...           79.345000
# max        75.950000            37.660000    ...          100.000000
#
#        Lessthan1Month_pct  onetotwoMonths_pct  twotothreeMonths_pct  \
# count           22.000000           22.000000             22.000000
# mean            87.409091           12.062727              0.390909
# std             13.650635           13.191300              0.659660
# min             46.840000            0.920000              0.000000
# 25%             87.560000            4.160000              0.000000
# 50%             91.990000            7.845000              0.095000
# 75%             95.555000           12.440000              0.557500
# max             99.080000           50.630000              2.530000
#
#        threeormoreMonths_pct  ClosExpl_pct  ClosExplDisp_pct  \
# count              22.000000     22.000000         22.000000
# mean                0.135000     85.093636         20.095000
# std                 0.379257     16.105825          6.622509
# min                 0.000000     55.270000         10.990000
# 25%                 0.000000     72.207500         15.085000
# 50%                 0.000000     94.040000         18.675000
# 75%                 0.030000     97.190000         22.775000
# max                 1.670000    100.000000         33.710000
#
#        ClosExplDispCom_pct  Payments_pct   UFDP_pct
# count            22.000000     22.000000  22.000000
# mean             13.589091     25.695455  58.682273
# std               5.149537      9.576080   6.681521
# min               6.100000     11.380000  46.940000
# 25%               9.372500     18.300000  54.047500
# 50%              12.955000     27.550000  59.545000
# 75%              16.215000     30.797500  62.877500
# max              24.050000     48.320000  72.370000
#
# [8 rows x 30 columns]

# %%
print(FnllBanklvldata_Tgt.isnull().sum())
# Out:
# BankID                   0
# AvgdaystoResolve         0
# MediandaystoResolve      0
# State9_pct               0
# State14_pct              0
# State43_pct              0
# State53_pct              0
# State47_pct              0
# BusinessPract_pct        0
# Communicn_pct            0
# LateFeeIntCharg_pct      0
# CIBILScore_pct           0
# CloseCancel_pct          0
# purchaser_pct            0
# DelayRecur_pct           0
# legal_pct                0
# MktOfferRwd_pct          0
# PaymentIssue_pct         0
# MortgageBroad_pct        0
# TeftFraudThreat_pct      0
# Mortgage_pct             0
# CreditCard_pct           0
# Lessthan1Month_pct       0
# onetotwoMonths_pct       0
# twotothreeMonths_pct     0
# threeormoreMonths_pct    0
# ClosExpl_pct             0
# ClosExplDisp_pct         0
# ClosExplDispCom_pct      0
# Payments_pct             0
# UFDP_pct                 0
# dtype: int64

# %%
dropc = ['ClosExpl_pct','ClosExplDispCom_pct','MortgageBroad_pct','MediandaystoResolve','Lessthan1Month_pct','onetotwoMonths_pct','BankID','State53_pct','twotothreeMonths_pct','State14_pct','Communicn_pct','purchaser_pct','State47_pct','threeormoreMonths_pct']
Testdata=FnllBanklvldata_Tgt.drop(dropc, axis=1)
